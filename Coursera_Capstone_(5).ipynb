# %% [markdown]
# <h1 align=center><font size = 5>Which Management District in Houston is Most Favorable for Opening a Restaurant?</font></h1>

# %% [markdown]
# Before we get the data and start exploring it, let's download all the dependencies that we will need.

# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geopy) (1.50)

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# !pip install BeautifulSoup4
# !pip install lxml

print('Libraries imported.')
# Out:
# Requirement already satisfied: BeautifulSoup4 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from BeautifulSoup4) (2.0.1)
# Requirement already satisfied: lxml in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (4.5.2)
# Libraries imported.

# %% [markdown]
# <a id='item1'></a>

# %% [markdown]
# ## 1. Download and Explore Dataset

# %% [markdown]
# Download and modify Houston management districts in the same way as the previous notebook.

# %%
# Import libraries
import pandas as pd
import numpy as np
import urllib.request
from bs4 import BeautifulSoup

# Specify the url
url = "https://en.wikipedia.org/wiki/List_of_Houston_neighborhoods"

# Open the url
page = urllib.request.urlopen(url)

# Parse the HTML from the URL into the parse tree format
soup = BeautifulSoup(page, "html5lib")

# Find the right table
right_table=soup.find_all("table", class_='wikitable sortable')[0]

# Sort rows
A=[]

# Read each row of the table
for row in right_table.findAll('tr'):
    cells=row.findAll('td')
    if len(cells)==3:
        # Check if the management district is not assigned
        if cells[1].find(text=True)!="Not assigned\n":
            # Find the name of the management district
            addas = cells[0].find(text=True)
            # Remove the \n at the end of each term
            adda = addas.replace("\n", "")
            A.append(adda)
                    
# Put into a dataframe and display
df=pd.DataFrame(A,columns=['Management District'])
df
# Out:
#                       Management District
# 0                      5 Corners District
# 1            Baybrook Management District
# 2                       Downtown District
# 3       East Downtown Management District
# 4     Generation Park Management District
# 5    Greater East End Management District
# 6   Greater Northside Management District
# 7                       Houston Southeast
# 8       International Management District
# 9            Memorial Management District
# 10                        Midtown Houston
# 11     Near Northwest Management District
# 12                 North Houston District
# 13          Southwest Management District
# 14      Spring Branch Management District
# 15                   Upper Kirby District
# 16                Uptown Houston District
# 17                     Westchase District

# %% [markdown]
# #### Load and explore the data

# %% [markdown]
# Next, let's compile it into one dataframe with latitude and longitude.

# %%
# Import file into a dataframe
import requests

# Instantiate latitude and longitude columns for df
lat=[]
long=[]

# Iterate through each district
for row in df['Management District']:
    # Find the associated latitude and longitude
    ad = ', Houston, TX'
    address = row+ad
    geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(address)
    test = geolocator.geocode('Nowhere, Houston, TX')
    if location!=test:
        addlat = location.latitude
        addlong = location.longitude
    else: 
        addlat = 'N/A'
        addlong = 'N/A'
    # Add the latitude and longitude to an array
    lat.append(addlat)
    long.append(addlong)
            
# Put into a dataframe, add latitude and longitude columns, and display a portion
newdf=df
newdf['Latitude']=lat
newdf['Longitude']=long
newdf
# Out:
#                       Management District Latitude Longitude
# 0                      5 Corners District      N/A       N/A
# 1            Baybrook Management District      N/A       N/A
# 2                       Downtown District  32.7826  -96.8088
# 3       East Downtown Management District      N/A       N/A
# 4     Generation Park Management District  29.9071    -95.18
# 5    Greater East End Management District      N/A       N/A
# 6   Greater Northside Management District      N/A       N/A
# 7                       Houston Southeast  29.7674  -95.3675
# 8       International Management District      N/A       N/A
# 9            Memorial Management District  29.9353  -95.4583
# 10                        Midtown Houston  29.7414  -95.3532
# 11     Near Northwest Management District  29.9317  -95.5094
# 12                 North Houston District  29.9447  -95.4161
# 13          Southwest Management District  29.9317  -95.5094
# 14      Spring Branch Management District      N/A       N/A
# 15                   Upper Kirby District      N/A       N/A
# 16                Uptown Houston District      N/A       N/A
# 17                     Westchase District  29.7294  -95.5739

# %%
# Generate a new dataframe, removing cells with no positional data
A=[]
B=[]
C=[]
index = 0
       
# Check that latitude and longitude is known
for rows in newdf['Latitude']: 
    # Record known values in an array
    if rows!='N/A':
        A.append(newdf.iloc[index,0])
        B.append(rows)
    index+=1
for rows in newdf['Longitude']:
    # Record known values in an array
    if rows!='N/A':
        C.append(rows)
# Generate and display new dataframe
dfnew = pd.DataFrame(A,columns=['Management District'])
dfnew['Latitude']=B
dfnew['Longitude']=C
dfnew
# Out:
#                    Management District   Latitude  Longitude
# 0                    Downtown District  32.782611 -96.808781
# 1  Generation Park Management District  29.907106 -95.179968
# 2                    Houston Southeast  29.767383 -95.367519
# 3         Memorial Management District  29.935331 -95.458260
# 4                      Midtown Houston  29.741414 -95.353201
# 5   Near Northwest Management District  29.931694 -95.509396
# 6               North Houston District  29.944719 -95.416074
# 7        Southwest Management District  29.931694 -95.509396
# 8                   Westchase District  29.729353 -95.573857

# %%
# Startup Foursquare API
CLIENT_ID = 'ROUSWCDE02ULBTFWSNIGUWYZVHHGBZIRCAEDNIQOKNQHD0R3' # your Foursquare ID
CLIENT_SECRET = 'ZKAGVFWWI153Q3SRMNSVMDHIETIJJUMQGHNVUGHE3PGHJJ15' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

LIMIT=103

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ROUSWCDE02ULBTFWSNIGUWYZVHHGBZIRCAEDNIQOKNQHD0R3
# CLIENT_SECRET:ZKAGVFWWI153Q3SRMNSVMDHIETIJJUMQGHNVUGHE3PGHJJ15

# %%
# Use venues functions from previous project for each district
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Management District', 
                  'Management District Latitude', 
                  'Management District Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
# Generate a list of venues in each district
houston_venues = getNearbyVenues(names=dfnew['Management District'],latitudes=dfnew['Latitude'],longitudes=dfnew['Longitude'])
houston_venues
# Out:
# Downtown District
# Generation Park Management District
# Houston Southeast
# Memorial Management District
# Midtown Houston
# Near Northwest Management District
# North Houston District
# Southwest Management District
# Westchase District
#                    Management District  Management District Latitude  \
# 0                    Downtown District                     32.782611
# 1                    Downtown District                     32.782611
# 2                    Downtown District                     32.782611
# 3                    Downtown District                     32.782611
# 4                    Downtown District                     32.782611
# 5                    Downtown District                     32.782611
# 6                    Downtown District                     32.782611
# 7                    Downtown District                     32.782611
# 8                    Downtown District                     32.782611
# 9                    Downtown District                     32.782611
# 10                   Downtown District                     32.782611
# 11                   Downtown District                     32.782611
# 12                   Downtown District                     32.782611
# 13                   Downtown District                     32.782611
# 14                   Downtown District                     32.782611
# 15                   Downtown District                     32.782611
# 16                   Downtown District                     32.782611
# 17                   Downtown District                     32.782611
# 18                   Downtown District                     32.782611
# 19                   Downtown District                     32.782611
# 20                   Downtown District                     32.782611
# 21                   Downtown District                     32.782611
# 22                   Downtown District                     32.782611
# 23                   Downtown District                     32.782611
# 24                   Downtown District                     32.782611
# 25                   Downtown District                     32.782611
# 26                   Downtown District                     32.782611
# 27                   Downtown District                     32.782611
# 28                   Downtown District                     32.782611
# 29                   Downtown District                     32.782611
# 30                   Downtown District                     32.782611
# 31                   Downtown District                     32.782611
# 32                   Downtown District                     32.782611
# 33                   Downtown District                     32.782611
# 34                   Downtown District                     32.782611
# 35                   Houston Southeast                     29.767383
# 36                   Houston Southeast                     29.767383
# 37                   Houston Southeast                     29.767383
# 38                   Houston Southeast                     29.767383
# 39                   Houston Southeast                     29.767383
# 40                   Houston Southeast                     29.767383
# 41                   Houston Southeast                     29.767383
# 42                   Houston Southeast                     29.767383
# 43                   Houston Southeast                     29.767383
# 44                   Houston Southeast                     29.767383
# 45                   Houston Southeast                     29.767383
# 46                   Houston Southeast                     29.767383
# 47        Memorial Management District                     29.935331
# 48        Memorial Management District                     29.935331
# 49        Memorial Management District                     29.935331
# 50        Memorial Management District                     29.935331
# 51        Memorial Management District                     29.935331
# 52        Memorial Management District                     29.935331
# 53        Memorial Management District                     29.935331
# 54        Memorial Management District                     29.935331
# 55                     Midtown Houston                     29.741414
# 56                     Midtown Houston                     29.741414
# 57                     Midtown Houston                     29.741414
# 58                     Midtown Houston                     29.741414
# 59                     Midtown Houston                     29.741414
# 60                     Midtown Houston                     29.741414
# 61                     Midtown Houston                     29.741414
# 62  Near Northwest Management District                     29.931694
# 63  Near Northwest Management District                     29.931694
# 64  Near Northwest Management District                     29.931694
# 65  Near Northwest Management District                     29.931694
# 66  Near Northwest Management District                     29.931694
# 67  Near Northwest Management District                     29.931694
# 68              North Houston District                     29.944719
# 69              North Houston District                     29.944719
# 70              North Houston District                     29.944719
# 71              North Houston District                     29.944719
# 72              North Houston District                     29.944719
# 73              North Houston District                     29.944719
# 74              North Houston District                     29.944719
# 75              North Houston District                     29.944719
# 76              North Houston District                     29.944719
# 77              North Houston District                     29.944719
# 78              North Houston District                     29.944719
# 79              North Houston District                     29.944719
# 80              North Houston District                     29.944719
# 81       Southwest Management District                     29.931694
# 82       Southwest Management District                     29.931694
# 83       Southwest Management District                     29.931694
# 84       Southwest Management District                     29.931694
# 85       Southwest Management District                     29.931694
# 86       Southwest Management District                     29.931694
# 87                  Westchase District                     29.729353
# 88                  Westchase District                     29.729353
# 89                  Westchase District                     29.729353
# 90                  Westchase District                     29.729353
# 91                  Westchase District                     29.729353
# 92                  Westchase District                     29.729353
# 93                  Westchase District                     29.729353
# 94                  Westchase District                     29.729353
# 95                  Westchase District                     29.729353
#
#     Management District Longitude                                    Venue  \
# 0                      -96.808781                                  Tutta's
# 1                      -96.808781                                  Ellen's
# 2                      -96.808781                           House of Blues
# 3                      -96.808781                   Y. O. Ranch Steakhouse
# 4                      -96.808781                      Wild Bill's Western
# 5                      -96.808781                        Medina Oven & Bar
# 6                      -96.808781                   The Sixth Floor Museum
# 7                      -96.808781           House of Blues Foundation Room
# 8                      -96.808781         la Madeleine Country French Café
# 9                      -96.808781                            Tiff's Treats
# 10                     -96.808781                    Dallas World Aquarium
# 11                     -96.808781                      1001 Wine & Spirits
# 12                     -96.808781                          Jinya Ramen Bar
# 13                     -96.808781                         The Grassy Knoll
# 14                     -96.808781                   Buzzbrews Victory Park
# 15                     -96.808781                             Dealey Plaza
# 16                     -96.808781           John F. Kennedy Memorial Plaza
# 17                     -96.808781                           Old Red Museum
# 18                     -96.808781                                      Neo
# 19                     -96.808781                  Dallas Holocaust Museum
# 20                     -96.808781                             Record Grill
# 21                     -96.808781                                 3 Eleven
# 22                     -96.808781                      Museum Store + Café
# 23                     -96.808781                       Urban Blend Coffee
# 24                     -96.808781                                   Subway
# 25                     -96.808781                       Rj Mexican Cuisine
# 26                     -96.808781                         Williams Chicken
# 27                     -96.808781                 Sonny Bryan's Smokehouse
# 28                     -96.808781                          Founder's Plaza
# 29                     -96.808781                   Dante's Italian Eatery
# 30                     -96.808781                                 7-Eleven
# 31                     -96.808781                   School Book Depository
# 32                     -96.808781                         Dallas City Tour
# 33                     -96.808781                Star Liquor, Beer, & Wine
# 34                     -96.808781    Woodall Rodgers Fwy & Riverfront Blvd
# 35                     -95.367519                                Paper Co.
# 36                     -95.367519                   Wortham Theater Center
# 37                     -95.367519                      Houston Grand Opera
# 38                     -95.367519                    Sesquicentennial Park
# 39                     -95.367519                      Be Someone graffiti
# 40                     -95.367519                        Downtown Aquarium
# 41                     -95.367519      A Tribute to American Statesmanship
# 42                     -95.367519             Houston Amtrak Station (HOS)
# 43                     -95.367519                      Aquarium Restaurant
# 44                     -95.367519                           The Big Bubble
# 45                     -95.367519                          Mount Rush Hour
# 46                     -95.367519                       A Better Bail Bond
# 47                     -95.458260                          Jack in the Box
# 48                     -95.458260                                    Shell
# 49                     -95.458260          New LA Crawfish Boil Restaurant
# 50                     -95.458260                     Hang Xanh Sandwiches
# 51                     -95.458260                                Hung Dong
# 52                     -95.458260                     Dollar Fried Chicken
# 53                     -95.458260                   Papas Estilo Monterrey
# 54                     -95.458260                    TC Jester & Beltway 8
# 55                     -95.353201                            CrossFit EaDo
# 56                     -95.353201                        East End Hardware
# 57                     -95.353201                         Texas Art Asylum
# 58                     -95.353201                           Nancy’s Hustle
# 59                     -95.353201        YOGA EADO (East Downtown Houston)
# 60                     -95.353201                               Florabunda
# 61                     -95.353201                    Crossfit Urban Animal
# 62                     -95.509396                                   SUBWAY
# 63                     -95.509396         La Casa de Villa Mexican Kitchen
# 64                     -95.509396              Hollister & Tomball Parkway
# 65                     -95.509396                       Bun Bo Hue Co Do 2
# 66                     -95.509396                   249 sports bar + grill
# 67                     -95.509396  Zoyto--Same Day Shipping Before 2PM CST
# 68                     -95.416074                                      GNC
# 69                     -95.416074                              Finish Line
# 70                     -95.416074                            Champs Sports
# 71                     -95.416074         Fitness Connection - Greenspoint
# 72                     -95.416074                                Dillard's
# 73                     -95.416074            Greenspoint Plaza 6 Cafeteria
# 74                     -95.416074                   Carnival @ Greenspoint
# 75                     -95.416074                              Foot Locker
# 76                     -95.416074                            Vitamin World
# 77                     -95.416074                                   Sbarro
# 78                     -95.416074                Luna's Mexican Restaurant
# 79                     -95.416074                          Greenpoint Mall
# 80                     -95.416074                               Food Court
# 81                     -95.509396                                   SUBWAY
# 82                     -95.509396         La Casa de Villa Mexican Kitchen
# 83                     -95.509396              Hollister & Tomball Parkway
# 84                     -95.509396                       Bun Bo Hue Co Do 2
# 85                     -95.509396                   249 sports bar + grill
# 86                     -95.509396  Zoyto--Same Day Shipping Before 2PM CST
# 87                     -95.573857                             CVS pharmacy
# 88                     -95.573857                                   Redbox
# 89                     -95.573857                                   Redbox
# 90                     -95.573857                                    Shell
# 91                     -95.573857    Texas Training and Conference Centers
# 92                     -95.573857                         Annie's Boutique
# 93                     -95.573857                   Home2 Suites by Hilton
# 94                     -95.573857                          Floral Concepts
# 95                     -95.573857                     Advanced Muscle Care
#
#     Venue Latitude  Venue Longitude                   Venue Category
# 0        32.781305       -96.807423                      Pizza Place
# 1        32.781989       -96.807682  Southern / Soul Food Restaurant
# 2        32.785033       -96.808221                      Music Venue
# 3        32.781296       -96.806402                       Steakhouse
# 4        32.781294       -96.806734                        Gift Shop
# 5        32.785579       -96.809745              Moroccan Restaurant
# 6        32.779994       -96.808609                   History Museum
# 7        32.785145       -96.808369                           Lounge
# 8        32.784763       -96.807906                French Restaurant
# 9        32.782551       -96.804600                           Bakery
# 10       32.783495       -96.805215                         Aquarium
# 11       32.782437       -96.805737                     Liquor Store
# 12       32.786134       -96.809117                 Ramen Restaurant
# 13       32.779391       -96.808541              Monument / Landmark
# 14       32.785440       -96.809478                       Restaurant
# 15       32.778724       -96.808316                            Plaza
# 16       32.779012       -96.806865                            Plaza
# 17       32.778743       -96.807514                   History Museum
# 18       32.786195       -96.809321                      Pizza Place
# 19       32.780585       -96.807610                   History Museum
# 20       32.779976       -96.806781              American Restaurant
# 21       32.781124       -96.806708                     Cocktail Bar
# 22       32.779581       -96.808008                        Gift Shop
# 23       32.780778       -96.805500                      Coffee Shop
# 24       32.779869       -96.807604                   Sandwich Place
# 25       32.781539       -96.806839               Mexican Restaurant
# 26       32.781317       -96.804626              Fried Chicken Joint
# 27       32.780805       -96.806366                        BBQ Joint
# 28       32.779575       -96.806598                            Plaza
# 29       32.780705       -96.806116               Italian Restaurant
# 30       32.780245       -96.805624                Convenience Store
# 31       32.780270       -96.808430                   History Museum
# 32       32.779636       -96.808380       Tourist Information Center
# 33       32.781556       -96.804745                     Liquor Store
# 34       32.781971       -96.814044                     Intersection
# 35       29.768454       -95.366900                      Coffee Shop
# 36       29.763353       -95.365663                          Theater
# 37       29.763623       -95.365204                     Concert Hall
# 38       29.764214       -95.365794                             Park
# 39       29.771029       -95.367818                       Public Art
# 40       29.764270       -95.367379                         Aquarium
# 41       29.771323       -95.366929              Monument / Landmark
# 42       29.767238       -95.367509                    Train Station
# 43       29.764608       -95.367273               Seafood Restaurant
# 44       29.764156       -95.365861                 Sculpture Garden
# 45       29.771321       -95.366926                       Public Art
# 46       29.767503       -95.372052                           Lawyer
# 47       29.936233       -95.458513             Fast Food Restaurant
# 48       29.936800       -95.458926                      Gas Station
# 49       29.933481       -95.457604               Seafood Restaurant
# 50       29.933554       -95.457531            Vietnamese Restaurant
# 51       29.933179       -95.457445                           Market
# 52       29.937199       -95.460102              Fried Chicken Joint
# 53       29.932792       -95.456774                       Food Truck
# 54       29.938071       -95.455158                     Intersection
# 55       29.740358       -95.352959             Gym / Fitness Center
# 56       29.742132       -95.350884                              Bar
# 57       29.742839       -95.355727              Arts & Crafts Store
# 58       29.745772       -95.352201       Modern European Restaurant
# 59       29.740429       -95.353175                      Yoga Studio
# 60       29.741126       -95.351620                      Flower Shop
# 61       29.743303       -95.348939                              Gym
# 62       29.931490       -95.510149                   Sandwich Place
# 63       29.931112       -95.510008               Mexican Restaurant
# 64       29.931516       -95.509187                     Intersection
# 65       29.930721       -95.509450            Vietnamese Restaurant
# 66       29.931197       -95.509889                              Bar
# 67       29.934229       -95.505814                 Business Service
# 68       29.945597       -95.411736                  Supplement Shop
# 69       29.946231       -95.411861                       Shoe Store
# 70       29.946372       -95.412447                       Shoe Store
# 71       29.945154       -95.413729                              Gym
# 72       29.942850       -95.411509                 Department Store
# 73       29.945766       -95.414903                             Café
# 74       29.944084       -95.414857                       Theme Park
# 75       29.945024       -95.411590                       Shoe Store
# 76       29.946505       -95.414902                  Supplement Shop
# 77       29.943707       -95.412758                      Pizza Place
# 78       29.945534       -95.412114               Mexican Restaurant
# 79       29.946175       -95.411527                    Movie Theater
# 80       29.944880       -95.411227              American Restaurant
# 81       29.931490       -95.510149                   Sandwich Place
# 82       29.931112       -95.510008               Mexican Restaurant
# 83       29.931516       -95.509187                     Intersection
# 84       29.930721       -95.509450            Vietnamese Restaurant
# 85       29.931197       -95.509889                              Bar
# 86       29.934229       -95.505814                 Business Service
# 87       29.728176       -95.571066                         Pharmacy
# 88       29.727820       -95.571983                      Video Store
# 89       29.728358       -95.571179                      Video Store
# 90       29.732408       -95.576046                      Gas Station
# 91       29.728189       -95.573915                     Home Service
# 92       29.727564       -95.574172                    Jewelry Store
# 93       29.730684       -95.571080                            Hotel
# 94       29.727320       -95.576385                      Flower Shop
# 95       29.726988       -95.576134                   Massage Studio

# %% [markdown]
# #### Create a data set

# %%
# one hot encoding
houston_onehot = pd.get_dummies(houston_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
houston_onehot['Management District'] = houston_venues['Management District'] 

# move neighborhood column to the first column
fixed_columns = [houston_onehot.columns[-1]] + list(houston_onehot.columns[:-1])
manhattan_onehot = houston_onehot[fixed_columns]

houston_grouped = houston_onehot.groupby('Management District').mean().reset_index()

num_top_venues=10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Management District']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))
   
    # create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Management District'] = houston_grouped['Management District']

for ind in np.arange(houston_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(houston_grouped.iloc[ind, :], num_top_venues)

# %%
# Generate restaurant score for each management district
length=len(neighborhoods_venues_sorted['Management District'])
restscores=np.zeros(length)
restnum=np.zeros(length)
restpop=np.zeros(length)
index=0

# Check the first through tenth most common venues for each district
for row in neighborhoods_venues_sorted:
    indexes=0
    for i in neighborhoods_venues_sorted[row]:
        # Search for restaurant or restaurant related venues
        # For each competitor, reduce restaurant score
        # Increase restaurant score if restaurants are popular
        if i.find('Restaurant')!=-1:
            if index<10:
                restnum[indexes]+=1
                restpop[indexes]+=11-index
        if i.find('Food')!=-1:
            if index<10:
                restnum[indexes]+=1
                restpop[indexes]+=11-index
        if i.find('Bar')!=-1:
            if index<10:
                restnum[indexes]+=1
                restpop[indexes]+=11-index
        if i.find('Place')!=-1:
            if index<10:
                restnum[indexes]+=1
                restpop[indexes]+=11-index
        if i.find('Joint')!=-1:
            if index<10:
                restnum[indexes]+=1
                restpop[indexes]+=11-index
        if i.find('Coffee')!=-1:
            if index<10:
                restnum[indexes]+=1
                restpop[indexes]+=11-index
        if i.find('Bakery')!=-1:
            if index<10:
                restnum[indexes]+=1
                restpop[indexes]+=11-index
        if index<10:
            if restnum[indexes]!=0:
                restscores[indexes]+=float(restpop[indexes])/float(restnum[indexes])
        indexes+=1
    index+=1

# %%
# add restaurant score to a dataframe
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', restscores)

houston_merged = dfnew

# merge houston_grouped with houston_data to add latitude/longitude for each neighborhood
houston_merged = houston_merged.join(neighborhoods_venues_sorted.set_index('Management District'), on='Management District')

houston_merged # check the last columns!
# Out:
#                    Management District   Latitude  Longitude  Cluster Labels  \
# 0                    Downtown District  32.782611 -96.808781       35.166667
# 1  Generation Park Management District  29.907106 -95.179968             NaN
# 2                    Houston Southeast  29.767383 -95.367519       56.000000
# 3         Memorial Management District  29.935331 -95.458260       78.433333
# 4                      Midtown Houston  29.741414 -95.353201       64.833333
# 5   Near Northwest Management District  29.931694 -95.509396       73.866667
# 6               North Houston District  29.944719 -95.416074       48.000000
# 7        Southwest Management District  29.931694 -95.509396       73.866667
# 8                   Westchase District  29.729353 -95.573857        2.000000
#
#    1st Most Common Venue 2nd Most Common Venue       3rd Most Common Venue  \
# 0         History Museum                 Plaza                Liquor Store
# 1                    NaN                   NaN                         NaN
# 2             Public Art                  Park                 Coffee Shop
# 3   Fast Food Restaurant    Seafood Restaurant                      Market
# 4            Yoga Studio                   Bar  Modern European Restaurant
# 5  Vietnamese Restaurant          Intersection          Mexican Restaurant
# 6             Shoe Store       Supplement Shop         American Restaurant
# 7  Vietnamese Restaurant          Intersection          Mexican Restaurant
# 8            Video Store           Flower Shop                 Gas Station
#
#   4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0           Pizza Place             Gift Shop          Cocktail Bar
# 1                   NaN                   NaN                   NaN
# 2              Aquarium         Train Station                Lawyer
# 3          Intersection           Gas Station   Fried Chicken Joint
# 4  Gym / Fitness Center                   Gym           Flower Shop
# 5                   Bar      Business Service        Sandwich Place
# 6                   Gym    Mexican Restaurant         Movie Theater
# 7                   Bar      Business Service        Sandwich Place
# 8         Jewelry Store                 Hotel        Massage Studio
#
#   7th Most Common Venue  8th Most Common Venue 9th Most Common Venue  \
# 0           Coffee Shop      Convenience Store     French Restaurant
# 1                   NaN                    NaN                   NaN
# 2               Theater    Monument / Landmark          Concert Hall
# 3            Food Truck  Vietnamese Restaurant                  Café
# 4   Arts & Crafts Store                 Bakery      Business Service
# 5                   Gym    Fried Chicken Joint           Gas Station
# 6           Pizza Place                   Café      Department Store
# 7                   Gym    Fried Chicken Joint           Gas Station
# 8          Home Service               Pharmacy     French Restaurant
#
#   10th Most Common Venue
# 0    Fried Chicken Joint
# 1                    NaN
# 2     Seafood Restaurant
# 3              BBQ Joint
# 4     Italian Restaurant
# 5              Gift Shop
# 6             Theme Park
# 7              Gift Shop
# 8    Fried Chicken Joint

# %%
# create map
latitude = 29.8
longitude = -95.3
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
colors_array = cm.rainbow(np.linspace(0, 1, 5))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# Convert cluster labels to integers
houston_merged['Cluster Labels']=houston_merged['Cluster Labels'].fillna(0).astype('int')

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(houston_merged['Latitude'], houston_merged['Longitude'], houston_merged['Management District'], houston_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Restaurant Score ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[round(cluster/30)-1],
        fill=True,
        fill_color=rainbow[round(cluster/30)-1],
        fill_opacity=0.7).add_to(map_clusters)

# Display map based on restaurant score.  
# Lighter colors are greater restaurant scores
macks = houston_merged['Cluster Labels'].max()

index = 0
for row in houston_merged['Cluster Labels']:
    if round(row)==macks:
        recommend = houston_merged.iloc[index,0]
    index+=1
print('The district most suitable for opening a restaurant is: ',recommend)
map_clusters
# Out:
# The district most suitable for opening a restaurant is:  Memorial Management District
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <hr>
#
# Copyright &copy; 2018 [Cognitive Class](https://cognitiveclass.ai/?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/).
